# %% [markdown]
# # Setup

# %%
# make sure you're in the categories env when you run this notebook

import glob, os, ast, warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from bambi import Model
import scipy.stats as stats
import random
# %run 'Tools/preprocess_mturk_data.py'
#from Tools.preprocess_mturk_data import process_mturk_csv
warnings.filterwarnings(action='once')
warnings.filterwarnings("ignore", category=DeprecationWarning)

# set plotting style 
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_context("poster")
sns.set(style="ticks",font="Arial",font_scale=2)

# pd settings
pd.set_option('display.max_columns', None)

# do we need to pre-process data?
if_preprocess = 1;

# %% [markdown]
# # Preprocess data and clean outliers
# We use a function to preprocess the data (loading individual data, concatenating them, and seperating into the different experimental phases), and then load the summary csvs.
# We start by loading data from all participants, then we check for outliers and remove them.

# %% [markdown]
# ### preprocess data

# %%
# if we need to preprocess the data, run this line
if (if_preprocess==1):
    # preprocess
    process_mturk_csv('../../../../Art_experiment/Java_experiment/Version11/Data', 'condition', 'Exp1')
    
    # load preprocessed csvs
    keys = ["ratings", "deliberation", "interference", "reward_learning", "final_decisions", "memory", "outcome_evaluation", "all_data", "all_interaction_data", "debrief"]
    path_to_data = "../Data/Exp1/Summary_data/all_subs"
    dfs_all_subs = {} # create a dictionary

    for i, key in enumerate(keys):
        dfs_all_subs[key] = pd.read_csv(os.path.join(path_to_data, key + ".csv"))
        if "Unnamed: 0" in dfs_all_subs[key].columns:
            dfs_all_subs[key] = dfs_all_subs[key].drop(columns = "Unnamed: 0")

    # check how many non-responses we have
    no_responses_final_decisions = dfs_all_subs["final_decisions"].groupby("PID").agg(
    total = ("rt",lambda x: len(x)),
    n_nan = ("rt", lambda x: pd.isnull(x).sum()),
    percent = ("rt",lambda x: pd.isnull(x).sum()/len(x)*100))
    print("mean percent of non responses:" + str(round(no_responses_final_decisions.percent.mean(),2)))
    
    # check duration of experiment
    subs = np.unique(dfs_all_subs["all_data"].PID)
    duration = pd.DataFrame(columns=["PID", "minutes"])
    for i in range(len(subs)):
        x = dfs_all_subs["all_data"].loc[dfs_all_subs["all_data"].PID == subs[i]]
        duration.loc[i,"PID"] = subs[i];
        duration.loc[i,"minutes"] = (x.loc[x.category == "debreif_end","time_elapsed"].iloc[0] - x.loc[x.category == "full_screen","time_elapsed"].iloc[0])/60000;
    print("mean duration of experiment:" + str(round(duration.minutes.mean(),2)))
    
    ## compute bonus money 
    bonus_money = dfs_all_subs["all_data"].loc[dfs_all_subs["all_data"].category == "debreif_clear_instructions",["PID","total_reward_tally"]].reset_index().drop(columns="index")
    fd_bonus = 2; n_FD_trials = 256; deliberation_reward_tally = 1.5
    bonus_per_trial = fd_bonus/(n_FD_trials/2); 
    for index, row in bonus_money.iterrows():
        bonus_money.loc[index, "computed_bonus"] = round(sum(dfs_all_subs["final_decisions"].loc[(dfs_all_subs["final_decisions"]["PID"] == bonus_money.loc[index, "PID"]) & (dfs_all_subs["final_decisions"]["rt"].notna() & (dfs_all_subs["final_decisions"]["chosen_trial"]==1)),"higher_outcome_chosen"]) * bonus_per_trial + deliberation_reward_tally, 2)

    # load subjects log to compute bonus money
    if os.path.exists('../../../../Art_experiment/Java_experiment/Version11/Data/subs_log/subs_log.csv'):
        worker_id = pd.read_csv("../../../../Art_experiment/Java_experiment/Version11/Data/subs_log/subs_log.csv").rename(columns = {"Actual Completion Code": "PID"})
        worker_id = worker_id.loc[worker_id.ApprovalStatus == "Pending",]
        worker_id = worker_id[["AmazonIdentifier", "PID"]]
        bonus = worker_id.merge(bonus_money, on="PID", how="left")
        bonus = bonus[["AmazonIdentifier", "total_reward_tally"]]
        bonus.rename_axis(None)
        bonus.to_csv("../../../../Art_experiment/Java_experiment/Version11/Data/Bonus/bonus.csv", header=False, index=False)
    
    # find outlier subjects
    blur_focus_criterion = 25;
    missed_instructions_criterion = 10; 
    final_decisions_non_responses_criterion = 25; 
    full_screen_criterion = 10;
    below_chance_chosen_final_decisions_criterion = 0.5;
    warning_events, outlier_subs = find_outlier_subs(dfs_all_subs["final_decisions"], dfs_all_subs["all_data"], dfs_all_subs["all_interaction_data"], blur_focus_criterion, missed_instructions_criterion, final_decisions_non_responses_criterion, full_screen_criterion, below_chance_chosen_final_decisions_criterion)
    print("outlier subs:")
    print(outlier_subs)
    # remove outlier subjects
    keys = ["ratings", "deliberation", "interference", "reward_learning", "final_decisions", "memory", "outcome_evaluation", "all_data", "all_interaction_data", "debrief"]
    dfs = {} # create a dictionary
    for i, key in enumerate(keys):
        dfs[key] = remove_outlier_subs(outlier_subs, dfs_all_subs[key], key, "Exp1")
    # remove non responses from decisions df
    dfs["final_decisions"] = dfs["final_decisions"][~pd.isnull(dfs["final_decisions"]["rt"])]
    # show how many subjects were left 
    print("after removal of outliers, n = " + str(len(np.unique(dfs["final_decisions"].PID))))
# Out:
# /Users/nataliebiderman/Dropbox/NatalieFolder/Columbia_University/2.Natalie/Shohamy_Lab/Research/Counterfactuals_project/Gershman/counterfactuals_actor_critic_model/Interference_exp/Analysis/Tools/preprocess_mturk_data.py:200: FutureWarning: The default value of regex will change from True to False in a future version.
#   debrief["response"] = debrief.responses.str.replace('{"Q0":','').str.replace('}','').str.replace('"','')
# /Users/nataliebiderman/Dropbox/NatalieFolder/Columbia_University/2.Natalie/Shohamy_Lab/Research/Counterfactuals_project/Gershman/counterfactuals_actor_critic_model/Interference_exp/Analysis/Tools/preprocess_mturk_data.py:200: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   debrief["response"] = debrief.responses.str.replace('{"Q0":','').str.replace('}','').str.replace('"','')
# ...

# %% [markdown]
# # Load clean data

# %%
keys = ["ratings", "deliberation", "interference", "reward_learning", \
        "final_decisions", "memory", "outcome_evaluation", "all_data", "all_interaction_data", "debrief"]
path_to_data = "../Data/Exp1/Summary_data/non_outlier_subs"
dfs = {} # create a dictionary

for i, key in enumerate(keys):
    dfs[key] = pd.read_csv(os.path.join(path_to_data, key + ".csv"))
    if "Unnamed: 0" in dfs[key].columns:
            dfs[key] = dfs[key].drop(columns = "Unnamed: 0")

# remove non responses from final decisions
dfs["final_decisions"] = dfs["final_decisions"][~pd.isnull(dfs["final_decisions"]["rt"])]

# %%
print("n = " + str(len(np.unique(dfs["final_decisions"].PID))))
# Out:
# n = 315

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Choices in Deliberation and Interference phase

# %% [markdown]
# ### Probability to choose an item in the deliberation phase

# %%
# logistic plots
sns.lmplot(data=dfs["deliberation"], x="zscored_delta_ratings", y="left_chosen", hue="condition",
               logistic=True, truncate=False, scatter=False);

# %% [markdown]
# ### Probability to choose the novel item in Interference phase

# %%
dfs["interference"]["novel_chosen"] = (dfs["interference"]["novel_left"] == dfs["interference"]["left_chosen"]).astype(int)
novel_inter = dfs["interference"].groupby("PID").agg(novel_chosen = ('novel_chosen', 'mean')).reset_index()
sns.violinplot(x=novel_inter["novel_chosen"]);

# %% [markdown]
# ## Check whether manipulation worked
# Is the manipulatuon worked we would expect better memory for the repetition pairs compared to the pairs that had retroactive interference. We observed no difference between conditions.

# %%
pairs_acc = dfs["memory"].groupby(["PID","condition"]).agg(pairs_acc = ('pairs_acc', 'mean'),
                                                           zscored_rt = ('zscored_rt_pairs', 'mean')).reset_index()
pairs_acc["condition"] = pairs_acc["condition"].replace({0: "Repetition", 1: "Interference"})

# %%
# plot memory performance
ax = sns.catplot(data = pairs_acc, 
                x="condition", y="pairs_acc", kind="bar", ci=95, alpha=0.5, capsize=.2).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="Memory accuracy",xlabel="Condition", title="Pairs memory - accuracy")
ax = sns.swarmplot(data=pairs_acc, x="condition", y="pairs_acc")
#plt.savefig('Plots/memory.png', dpi=300)

bx = sns.catplot(data = pairs_acc, 
                x="condition", y="zscored_rt", kind="bar", ci=95, alpha=0.5, capsize=.2).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="RT (zscored)",xlabel="Condition", title="Pairs memory - RT")
# Out:
# /Users/nataliebiderman/Software/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 36.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nataliebiderman/Software/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 43.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Analysis of decision bias
# first let's look at inverse bias across the conditions and then within them. We were not able to replicate the inverse bias in neither. We do see an interesting RT effect for chosen pairs - responses to Repetition pairs are faster than Interference pairs, suggesting some enhanced learning of reward for chosen pairs. This is the only difference we found between conditions.

# %%
p_gain = dfs["final_decisions"].groupby(["PID","chosen_trial","condition"]).agg(
    p_gain = ('higher_outcome_chosen','mean'),
    zscored_rt = ('zscored_rt', 'mean')).reset_index()
p_gain["chosen_trial"] = p_gain["chosen_trial"].replace({0: "Unchosen Pairs", 1: "Chosen Pairs"})
p_gain["condition"] = p_gain["condition"].replace({0: "Repetition", 1: "Interference"})

# %%
p_gain.groupby(["chosen_trial", "condition"]).agg({'p_gain': ('mean', 'sem'), 'zscored_rt': ('mean', 'sem')}).reset_index()
# Out:
#      chosen_trial     condition    p_gain           zscored_rt
#                                      mean       sem       mean       sem
# 0    Chosen Pairs  Interference  0.909054  0.007591  -0.249807  0.012184
# 1    Chosen Pairs    Repetition  0.905862  0.007890  -0.236621  0.011163
# 2  Unchosen Pairs  Interference  0.484918  0.013242   0.240912  0.012213
# 3  Unchosen Pairs    Repetition  0.440429  0.013358   0.248572  0.012535

# %%
ax = sns.catplot(data = p_gain, 
                x="chosen_trial", y="p_gain", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=.2).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="p(Choose Gain)",xlabel="Pair type", title="Inverse bias across conditions")
ax = sns.swarmplot(data=p_gain, x="chosen_trial", y="p_gain", dodge=True)
#ax.get_legend().set_visible(False)
# Out:
# /Users/nataliebiderman/Software/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 52.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.catplot(data = p_gain, 
                x="chosen_trial", y="p_gain", hue="condition", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=.2).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="p(Choose Gain)",xlabel="Pair type", title="Inverse bias in Final Decisions")
ax = sns.swarmplot(data=p_gain, x="chosen_trial", y="p_gain", hue='condition', dodge=True, size=4.5, alpha=0.7)
ax.get_legend().set_visible(False)

plt.savefig('Plots/p_gain.png', dpi=300)

ax = sns.catplot(data = p_gain, 
                x="chosen_trial", y="zscored_rt", hue='condition', kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=.2).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="z-scored RT",xlabel="Pair type", title="RT in Final Decisions")
ax = sns.swarmplot(data=p_gain, x="chosen_trial", y="zscored_rt", hue='condition', dodge=True, alpha=0.7)
ax.get_legend().set_visible(False)
# Out:
# /Users/nataliebiderman/Software/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nataliebiderman/Software/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nataliebiderman/Software/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nataliebiderman/Software/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
condition_spread = p_gain.pivot_table(index=["PID","chosen_trial"],columns="condition",values="p_gain").reset_index()
condition_spread["Condition Difference"] = condition_spread["Interference"] - condition_spread["Repetition"]
condition_spread.groupby(["chosen_trial"]).agg({'Condition Difference': ('mean', 'sem')}).reset_index()
# Out:
#      chosen_trial Condition Difference
#                                   mean       sem
# 0    Chosen Pairs             0.003192  0.004774
# 1  Unchosen Pairs             0.044489  0.018191

# %%
ax = sns.catplot(data = condition_spread, 
                x="chosen_trial", y="Condition Difference", kind="bar", ci=95, aspect=1.5, capsize=.2).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="Condition Difference\n(p(gain) Interference - p(gain) Repetition)",xlabel="Pair type")
ax = sns.swarmplot(data=condition_spread, x="chosen_trial", y="Condition Difference", dodge=True, alpha=0.4)
#ax.get_legend().set_visible(False)
# Out:
# /Users/nataliebiderman/Software/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 39.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(data=dfs["final_decisions"], x="zscored_delta_ratings", y="higher_outcome_chosen", hue="condition",col="chosen_trial",
               logistic=True, truncate=False, scatter=False).map(
        plt.axhline, y=0.5, ls='--', c='black').map(
    plt.axvline, x=0, ls='--', c='black').set(
        ylabel="p(choose S+)",xlabel="delta ratings");

# %%
sns.lmplot(data=dfs["final_decisions"], x="zscored_rt", y="higher_outcome_chosen", hue="condition",col="chosen_trial",
               logistic=True, truncate=False, scatter=False).map(
        plt.axhline, y=0.5, ls='--', c='black').map(
    plt.axvline, x=0, ls='--', c='black').set(
        ylabel="p(choose S+)",xlabel="RT (zscore)");

# %% [markdown]
# Let's see if we can replicate the RT findings from our previous studies (i.e., faster responses to no gain in unchosen items). This was also not replicated here.

# %%
rt_gain_choice = dfs["final_decisions"].groupby(["PID","chosen_trial","condition","higher_outcome_chosen"]).agg(
    zscored_rt = ('zscored_rt', 'mean')).reset_index()
rt_gain_choice["chosen_trial"] = rt_gain_choice["chosen_trial"].replace({0: "Unchosen Pairs", 1: "Chosen Pairs"})
rt_gain_choice["condition"] = rt_gain_choice["condition"].replace({0: "Repetition", 1: "Interference"})

# plot
ax = sns.catplot(data = rt_gain_choice, 
                col="chosen_trial", hue="higher_outcome_chosen", y="zscored_rt", x='condition', kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="z-scored RT",xlabel="Gain chosen")

plt.savefig('Plots/rt_choose_gain.png', dpi=300)

# %% [markdown]
# ### Decision bias and memory
# This was the main effect replicated across different tasks: a strong correlation between pairs memory and inverse bias (chosen minus unchosen pairs). Here this effect seems to replicate, but without a difference between conditions

# %%
p_gain_memory = p_gain.merge(pairs_acc.drop(columns="zscored_rt"), on=["PID","condition"], how="inner")
#p_gain_memory

# %%
p_gain_spread = p_gain_memory.drop(columns=["pairs_acc", "zscored_rt"]).pivot_table(index=["PID","condition"],columns="chosen_trial",values="p_gain").reset_index()
p_gain_spread["inverse bias"] = p_gain_spread["Chosen Pairs"] - p_gain_spread["Unchosen Pairs"]
rt_spread = p_gain_memory.drop(columns=["p_gain","pairs_acc"]).pivot_table(index=["PID","condition"],columns="chosen_trial",values="zscored_rt").reset_index()
rt_spread["inverse zscored rt"] = rt_spread["Chosen Pairs"] - rt_spread["Unchosen Pairs"]
inverse_performance = p_gain_spread.drop(columns=["Chosen Pairs","Unchosen Pairs"]).merge(
   rt_spread.drop(columns=["Chosen Pairs","Unchosen Pairs"]), on=["PID","condition"]).merge(
   pairs_acc, on=["PID","condition"])

# %%
ax = sns.catplot(data = inverse_performance, 
                x="condition", y="inverse bias", kind="bar", ci=95, alpha=0.5, capsize=.2).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="Inverse bias\n(p(gain) chosen - p(gain) unchosen)",xlabel="Pair type")
ax = sns.swarmplot(data=inverse_performance, x="condition", y="inverse bias", dodge=True)
#ax.get_legend().set_visible(False)

# %%
sns.lmplot(data=p_gain_memory, x="pairs_acc", y="p_gain", col="chosen_trial", hue="condition", ci=95, truncate=False);

sns.lmplot(data=inverse_performance, x="pairs_acc", y="inverse bias", hue="condition", ci=95, truncate=False, aspect=1.2).set(xlabel="Pairs memory (accuracy)", ylabel="Inverse bias\n(p(gain) chosen - p(gain) unchosen)");
plt.savefig('Plots/memory_bias.png', dpi=300)

sns.lmplot(data=inverse_performance, x="pairs_acc", y="inverse zscored rt", hue="condition", ci=95, truncate=False, aspect=1.2).set(xlabel="Pairs memory (accuracy)", ylabel="Inverse zscored RT\n(RT chosen - RT unchosen)");

# %% [markdown]
# Now assess individual differences in memory and p(gain) between the different conditions

# %%
cond_spread_p_gain = p_gain_memory.drop(columns=["zscored_rt","pairs_acc"]).pivot_table(index=["PID","chosen_trial"],columns="condition",values="p_gain").reset_index()
cond_spread_p_gain["condition diff - choices"] = cond_spread_p_gain["Repetition"] - cond_spread_p_gain["Interference"]
cond_spread_rt = p_gain_memory.drop(columns=["p_gain","pairs_acc"]).pivot_table(index=["PID","chosen_trial"],columns="condition",values="zscored_rt").reset_index()
cond_spread_rt["condition diff - zscored rt"] = cond_spread_rt["Repetition"] - cond_spread_rt["Interference"]
cond_spread_pairs_acc = pairs_acc.pivot_table(index=["PID"],columns="condition",values="pairs_acc").reset_index()
cond_spread_pairs_acc["condition diff - pairs_acc"] = cond_spread_pairs_acc["Repetition"] - cond_spread_pairs_acc["Interference"]

cond_diff_performance = cond_spread_p_gain.drop(columns=["Repetition","Interference"]).merge(
    cond_spread_rt.drop(columns=["Repetition","Interference"]), on=["PID","chosen_trial"]).merge(
    cond_spread_pairs_acc.drop(columns=["Repetition","Interference"]), on=["PID"])

# %%
sns.lmplot(data=cond_diff_performance, x="condition diff - pairs_acc", y="condition diff - choices", hue="chosen_trial", ci=95, truncate=False, aspect=1.2).set(xlabel="Pairs memory difference\n(Repetition - Interference)", ylabel="p(gain) difference\n(Repetition - Interference)");
sns.lmplot(data=cond_diff_performance, x="condition diff - pairs_acc", y="condition diff - zscored rt", hue="chosen_trial", ci=95, truncate=False, aspect=1.2).set(xlabel="Pairs memory difference\n(Repetition - Interference)", ylabel="zscored RT difference\n(Repetition - Interference)");

# %% [markdown]
# ## Outcome evaluation

# %%
outcome_eval_summ = dfs["outcome_evaluation"].groupby(["PID", "condition", "stim_type", "outcome"]).agg(
    gain_estimation = ("outcome_eval_gain", "mean"),
    gain_estimation_rt = ("zscored_outcome_eval_rt", "mean"),
    confidence = ("outcome_eval_confidence","mean"),
    confidence_rt = ("zscored_outcome_eval_confidence_rt","mean")).reset_index()
outcome_eval_summ["condition"] =  outcome_eval_summ["condition"].replace({0: "Repetition", 1: "Interference"})
outcome_eval_summ["outcome"] =  outcome_eval_summ["outcome"].replace({-1: "No gain", 1: "Gain"})

ax = sns.catplot(data = outcome_eval_summ, 
                col="stim_type", x="outcome", y="gain_estimation", hue="condition", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="p(estimate as S+)")
#ax = sns.swarmplot(data=outcome_eval_summ, col="condition", x="stim_type", y="gain_estimation", hue='outcome', dodge=True)
#plt.savefig('Plots/outcome_eval.png', dpi=300)

ax = sns.catplot(data = outcome_eval_summ, 
                col="stim_type", x="outcome", y="gain_estimation_rt", hue="condition", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="RT (zscored)")

ax = sns.catplot(data = outcome_eval_summ, 
                col="stim_type", x="outcome", y="confidence", hue="condition", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=3.5, ls='--', c='black').set(
        ylabel="Confidence (1-6)")

ax = sns.catplot(data = outcome_eval_summ, 
                col="stim_type", x="outcome", y="confidence_rt", hue="condition", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="Confidence RT (zscored)")

# %% [markdown]
# # Divide subjects to two groups by performance

# %%
# divide subjects into two groups according to their performance in chosen pairs 
p_gain_chosen = dfs["final_decisions"].loc[dfs["final_decisions"].chosen_trial==1].groupby(["PID"]).agg(
    p_gain = ('higher_outcome_chosen','mean')).sort_values(by="p_gain").reset_index()
p_gain_chosen.loc[0:np.floor(len(p_gain_chosen)/2), "performance_group"] = "low"
p_gain_chosen.loc[np.ceil(len(p_gain_chosen)/2):len(p_gain_chosen), "performance_group"] = "high"
performance_group = p_gain_chosen[["PID","performance_group"]]

dfs["final_decisions"] = dfs["final_decisions"].merge(performance_group, on="PID")
dfs["memory"] = dfs["memory"].merge(performance_group, on="PID")
dfs["outcome_evaluation"] = dfs["outcome_evaluation"].merge(performance_group, on="PID")

# here we decide whether we want to remove the low performance subjects from further analysis
apply_strict_exclusion_criteria = 0;
if (apply_strict_exclusion_criteria==1):
    # find low performance subjects 
    chosen_p_gain_cutoff = 0.5
    memory_acc_cutoff = 0.5
    p_gain_chosen = dfs["final_decisions"].groupby(["PID","chosen_trial"]).agg(
        p_gain = ('higher_outcome_chosen','mean')).reset_index()
    low_performance_subs_p_gain = list(p_gain_chosen.loc[(p_gain_chosen.chosen_trial==1) & (p_gain_chosen.p_gain < chosen_p_gain_cutoff), "PID"])
    pairs_acc_high = dfs["memory"].groupby(["PID"]).agg(
        pairs_acc = ('pairs_acc','mean')).reset_index()
    low_performance_subs_pairs_acc = list(pairs_acc_high.loc[pairs_acc_high.pairs_acc < memory_acc_cutoff, "PID"])
    low_performance_subs = np.unique(low_performance_subs_p_gain + low_performance_subs_pairs_acc)
    # remove these subjects from dfs
    dfs["final_decisions"] = dfs["final_decisions"].loc[~dfs["final_decisions"].PID.isin(low_performance_subs)]
    dfs["memory"] = dfs["memory"].loc[~dfs["memory"].PID.isin(low_performance_subs)]
    dfs["outcome_evaluation"] = dfs["outcome_evaluation"].loc[~dfs["outcome_evaluation"].PID.isin(low_performance_subs)]

# %%
# memory

pairs_acc = dfs["memory"].groupby(["PID", "performance_group","condition"]).agg(pairs_acc = ('pairs_acc', 'mean'),
                                                                                zscored_rt = ('zscored_rt_pairs', 'mean')).reset_index()
pairs_acc["condition"] = pairs_acc["condition"].replace({0: "Repetition", 1: "Interference"})

pairs_acc.groupby(["performance_group","condition",]).agg({'pairs_acc': ('mean', 'sem')}).reset_index()

ax = sns.catplot(data = pairs_acc, 
                x="condition", y="pairs_acc", kind="bar", ci=95, alpha=0.5, capsize=.2, col="performance_group").map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="Memory accuracy",xlabel="Condition")
bx = sns.catplot(data = pairs_acc, 
                x="condition", y="zscored_rt", kind="bar", ci=95, alpha=0.5, capsize=.2, col="performance_group").map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="RT (zscored)",xlabel="Condition")

# choices in final decisions
p_gain = dfs["final_decisions"].groupby(["PID","performance_group","chosen_trial","condition"]).agg(
    p_gain = ('higher_outcome_chosen','mean'),
    zscored_rt = ('zscored_rt', 'mean')).reset_index()
p_gain["chosen_trial"] = p_gain["chosen_trial"].replace({0: "Unchosen Pairs", 1: "Chosen Pairs"})
p_gain["condition"] = p_gain["condition"].replace({0: "Repetition", 1: "Interference"})
ax = sns.catplot(data = p_gain, 
                x="chosen_trial", y="p_gain", col="performance_group",kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=.2).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="p(Choose Gain)",xlabel="Pair type")
ax = sns.swarmplot(data=p_gain, x="chosen_trial", y="p_gain", col="performance_group", dodge=True)
#ax.get_legend().set_visible(False)
sns.catplot(data = p_gain, 
                x="chosen_trial", y="p_gain", hue="condition", kind="bar", col="performance_group",ci=95, aspect=1.5, alpha=0.5, capsize=.2).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="p(Choose Gain)",xlabel="Pair type")

# rt in final decisions
rt_gain_choice = dfs["final_decisions"].groupby(["PID","performance_group","chosen_trial","condition","higher_outcome_chosen"]).agg(
    zscored_rt = ('zscored_rt', 'mean')).reset_index()
rt_gain_choice["chosen_trial"] = rt_gain_choice["chosen_trial"].replace({0: "Unchosen Pairs", 1: "Chosen Pairs"})
rt_gain_choice["condition"] = rt_gain_choice["condition"].replace({0: "Repetition", 1: "Interference"})
ax = sns.catplot(data = rt_gain_choice.loc[rt_gain_choice.chosen_trial=="Unchosen Pairs"], 
                col="performance_group", hue="higher_outcome_chosen", y="zscored_rt", x='condition', kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="z-scored RT",xlabel="Gain chosen")

# inverse bias and memory correlation
p_gain_memory = p_gain.merge(pairs_acc.drop(columns="zscored_rt"), on=["PID","performance_group","condition"], how="inner")

p_gain_spread = p_gain_memory.drop(columns=["pairs_acc", "zscored_rt"]).pivot_table(index=["PID","condition","performance_group"],columns="chosen_trial",values="p_gain").reset_index()
p_gain_spread["inverse bias"] = p_gain_spread["Chosen Pairs"] - p_gain_spread["Unchosen Pairs"]
rt_spread = p_gain_memory.drop(columns=["p_gain","pairs_acc"]).pivot_table(index=["PID","condition","performance_group"],columns="chosen_trial",values="zscored_rt").reset_index()
rt_spread["inverse zscored rt"] = rt_spread["Chosen Pairs"] - rt_spread["Unchosen Pairs"]
inverse_performance = p_gain_spread.drop(columns=["Chosen Pairs","Unchosen Pairs"]).merge(
   rt_spread.drop(columns=["Chosen Pairs","Unchosen Pairs"]), on=["PID","condition","performance_group"]).merge(
   pairs_acc, on=["PID","condition","performance_group"])

sns.lmplot(data=p_gain_memory.loc[p_gain_memory.chosen_trial=="Unchosen Pairs"], x="pairs_acc", y="p_gain", col="performance_group", hue="condition", ci=95, truncate=False).set(ylabel="p(select S+)\nUnchosen pairs");
sns.lmplot(data=p_gain_memory.loc[p_gain_memory.chosen_trial=="Chosen Pairs"], x="pairs_acc", y="p_gain", col="performance_group", hue="condition", ci=95, truncate=False).set(ylabel="p(select S+)\nChosen pairs");

sns.lmplot(data=inverse_performance, x="pairs_acc", y="inverse bias", hue="condition", col="performance_group",ci=95, truncate=False, aspect=1).set(xlabel="Pairs memory (accuracy)", ylabel="Inverse bias\n(p(gain) chosen - p(gain) unchosen)");


# outcome evaluation
outcome_eval_summ = dfs["outcome_evaluation"].groupby(["PID", "performance_group","stim_type","condition", "outcome"]).agg(
    gain_estimation = ("outcome_eval_gain", "mean"),
    gain_estimation_rt = ("zscored_outcome_eval_rt", "mean"),
    confidence = ("outcome_eval_confidence","mean"),
    confidence_rt = ("zscored_outcome_eval_confidence_rt","mean")).reset_index()
outcome_eval_summ["condition"] =  outcome_eval_summ["condition"].replace({0: "Repetition", 1: "Interference"})
outcome_eval_summ["outcome"] =  outcome_eval_summ["outcome"].replace({-1: "No gain", 1: "Gain"})

ax = sns.catplot(data = outcome_eval_summ.loc[outcome_eval_summ.performance_group=="high"], 
                x="outcome", y="gain_estimation", hue="condition", col="stim_type", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="p(estimate as S+)\nHigh group")

ax = sns.catplot(data = outcome_eval_summ.loc[outcome_eval_summ.performance_group=="low"], 
                x="outcome", y="gain_estimation", hue="condition", col="stim_type",kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0.5, ls='--', c='black').set(
        ylabel="p(estimate as S+)\nLow group")

ax = sns.catplot(data = outcome_eval_summ.loc[outcome_eval_summ.performance_group=="high"], 
                x="outcome", y="gain_estimation_rt", hue="condition", col="stim_type", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="RT (zscored)\nHigh group")

ax = sns.catplot(data = outcome_eval_summ.loc[outcome_eval_summ.performance_group=="low"], 
                x="outcome", y="gain_estimation_rt", hue="condition", col="stim_type", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=0, ls='--', c='black').set(
        ylabel="RT (zscored)\nLow group")

ax = sns.catplot(data = outcome_eval_summ.loc[outcome_eval_summ.performance_group=="high"], 
                x="outcome", y="confidence", hue="condition", col="stim_type", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=3.5, ls='--', c='black').set(
        ylabel="Confidence (1-6)\nHigh group")

ax = sns.catplot(data = outcome_eval_summ.loc[outcome_eval_summ.performance_group=="low"], 
                x="outcome", y="confidence", hue="condition", col="stim_type", kind="bar", ci=95, aspect=1.5, alpha=0.5, capsize=0.1).map(
        plt.axhline, y=3.5, ls='--', c='black').set(
        ylabel="Confidence (1-6)\nLow group")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ab2894c7d4f0> in <module>
#      26         plt.axhline, y=0.5, ls='--', c='black').set(
#      27         ylabel="p(Choose Gain)",xlabel="Pair type")
# ---> 28 ax = sns.swarmplot(data=p_gain, x="chosen_trial", y="p_gain", col="performance_group", dodge=True)
#      29 #ax.get_legend().set_visible(False)
#      30 sns.catplot(data = p_gain,
#
# ~/Software/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %% [markdown]
# # Debriefing

# %%
dfs["debrief"].iloc[0:20]
